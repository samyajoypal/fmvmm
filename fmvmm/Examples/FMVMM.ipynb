# %% [markdown]
# # Example: FMVMM (Mixtures of Identical and Non-Identical Distributions)

# %%
import os
os.chdir("../..")

# %%
# Let us first import necessary modules

from fmvmm.mixtures.FMVMM import fmvmm
from sklearn import datasets
from fmvmm.utils.utils_mixture import clustering_metrics

# %%
# LEt us first get iris data

iris = datasets.load_iris()

df = iris.data

# %%
# We can  fit mixtures of all possible combinations of identical and non-identical distributions.
#However, that might take quite an amount of time.

# Let us try all possible combinations of the following distributions: 
# Multivariate Generalized Hyperbolic,
# Skew Normal
# Multivariate Normal Inverse Gaussian
# Multivariate T
# Multivariate Skew T

dist = ["mghp", "mvsn", "mnig","mvt","mvst"]

#If you want to use the list of all the distributions do not provide list_of_dist argument.
#By default it will use the full list of distributions

model = fmvmm(n_clusters=3, list_of_dist = dist,debug= True)

model.fit(df)
# Out:
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 386, in _alphabar2chipsi
#     return float(chi), float(psi)
#            ~~~~~^^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 770, in fit
#     fit = fitghypmv(
#         x, lmbda=lmbda, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
# ...
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 381, in _alphabar2chipsi
#     chi = float(alpha_bar * numer / denom)
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_norminvgauss.py", line 200, in fit
#     fit = ghypmv.fitghypmv(
#         x, lmbda=-0.5, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 381, in _alphabar2chipsi
#     chi = float(alpha_bar * numer / denom)
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_norminvgauss.py", line 200, in fit
#     fit = ghypmv.fitghypmv(
#         x, lmbda=-0.5, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 381, in _alphabar2chipsi
#     chi = float(alpha_bar * numer / denom)
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_norminvgauss.py", line 200, in fit
#     fit = ghypmv.fitghypmv(
#         x, lmbda=-0.5, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 381, in _alphabar2chipsi
#     chi = float(alpha_bar * numer / denom)
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# Traceback (most recent call last):
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/mixtures/FMVMM.py", line 403, in fit
#     self.pi_not, self.alpha_not = fmm_kmeans_init(
#                                   ~~~~~~~~~~~~~~~^
#         self.data, self.k, self.dist_combs[l])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/utils/utils_fmm.py", line 72, in fmm_kmeans_init
#     alpha_not=[dist_comb[j].fit(np.array(data_cwise[j])) for j in range(k)]
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_norminvgauss.py", line 200, in fit
#     fit = ghypmv.fitghypmv(
#         x, lmbda=-0.5, alpha_bar=alpha_bar, mu=fmu, sigma=fsigma, gamma=fgamma,
#         symmetric=symmetric, standardize=standardize, nit=nit, reltol=reltol,
#         abstol=abstol, silent=silent, opt_pars=opt_pars)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 644, in fitghypmv
#     tmp_fit = scipy.optimize.minimize(gig_optfunc, thepars_v, args=(
#         mix_pars_fixed_v, pars_order, delta_sum, eta_sum, xi_sum, n), method='L-BFGS-B')
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_minimize.py", line 784, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#                            callback=callback, **options)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lbfgsb_py.py", line 413, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#                                   bounds=bounds,
#                                   finite_diff_rel_step=finite_diff_rel_step,
#                                   workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_optimize.py", line 310, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#                         finite_diff_rel_step, bounds, epsilon=epsilon,
#                         workers=workers)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 283, in __init__
#     self._update_fun()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/_lib/_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 427, in gig_optfunc
#     chi, psi = _alphabar2chipsi(alpha_bar, lmbda)
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/at/Documents/github_project_fmvmm/fmvmm/fmvmm/distributions/multivariate_genhyperbolic.py", line 381, in _alphabar2chipsi
#     chi = float(alpha_bar * numer / denom)
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# distribution fitted ['fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_t']
# distribution fitted ['fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_skew_t_smsn']
# distribution fitted ['fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_skew_t_smsn', 'fmvmm.distributions.multivariate_skew_t_smsn']
# distribution fitted ['fmvmm.distributions.multivariate_skew_t_smsn', 'fmvmm.distributions.multivariate_skew_t_smsn', 'fmvmm.distributions.multivariate_skew_t_smsn']
# Model fitted successfully

# %%
# Find the best model based on bic

model.best_mixture()
# Out:
# ['fmvmm.distributions.multivariate_t',
#  'fmvmm.distributions.multivariate_t',
#  'fmvmm.distributions.multivariate_t']

# %%
# Get BIC of all the fitted models

model.bic()
# Out:
# [np.float64(630.145472719892),
#  np.float64(624.7352466964535),
#  np.float64(710.1861816996595),
#  np.float64(620.3534457651036),
#  np.float64(705.8043593887822),
#  np.float64(847.5705067420049),
#  np.float64(619.0275715022021),
#  np.float64(656.9914241551409),
#  np.float64(798.7574219484185),
#  np.float64(952.7389143217716)]

# %%
# get information matrix and standard errors for all the fitted models

ims, ses = model.get_info_mat()

# %%
# get weighted information matrix and standard errors for all the fitted models

ims_w, ses_w = model.get_info_mat_soft()

# %%
# We can see Out of the fitted models which were successfull

model.worked()
# Out:
# Distribution Combinations That Could Be Fitted:
# 0 ['fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_skewnorm']
# 1 ['fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_t']
# 2 ['fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 3 ['fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_t']
# 4 ['fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 5 ['fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_skew_t_smsn', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 6 ['fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_t']
# 7 ['fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 8 ['fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_skew_t_smsn', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 9 ['fmvmm.distributions.multivariate_skew_t_smsn', 'fmvmm.distributions.multivariate_skew_t_smsn', 'fmvmm.distributions.multivariate_skew_t_smsn']

# %%
# We can see Out of the fitted models which were not successfull

model.not_worked()
# Out:
# Distribution Combinations That Could Not Be Fitted:
# 0 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_genhyperbolic']
# 1 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_skewnorm']
# 2 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_norminvgauss']
# 3 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_t']
# 4 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 5 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_skewnorm']
# 6 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_norminvgauss']
# 7 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_t']
# 8 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 9 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_norminvgauss']
# 10 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_t']
# 11 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 12 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_t']
# 13 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 14 ['fmvmm.distributions.multivariate_genhyperbolic', 'fmvmm.distributions.multivariate_skew_t_smsn', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 15 ['fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_norminvgauss']
# 16 ['fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_norminvgauss']
# 17 ['fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_t']
# 18 ['fmvmm.distributions.multivariate_skewnorm', 'fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 19 ['fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_norminvgauss']
# 20 ['fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_t']
# 21 ['fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 22 ['fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_t']
# 23 ['fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_t', 'fmvmm.distributions.multivariate_skew_t_smsn']
# 24 ['fmvmm.distributions.multivariate_norminvgauss', 'fmvmm.distributions.multivariate_skew_t_smsn', 'fmvmm.distributions.multivariate_skew_t_smsn']

# %%
# Luckily all models were successfull.

# We can get the MLEs for all the models

pi_list, alpha_list = model.get_params()

# %%
# let us now get the MLEs of the best model

pi_best, alpha_best = model.best_params()

print("pi: ", pi_best)
print("alpha: ", alpha_best)
# Out:
# pi:  [0.42666667 0.33333333 0.24      ]
# alpha:  [(array([5.96086899, 2.8376423 , 4.05928003, 1.1618888 ]), array([[0.23305969, 0.07155415, 0.13199134, 0.02847889],
#        [0.07155415, 0.09287426, 0.02926368, 0.00686498],
#        [0.13199134, 0.02926368, 0.3799496 , 0.21610546],
#        [0.02847889, 0.00686498, 0.21610546, 0.16233063]]), array([-1.2735831 , -2.58377104,  4.21371348,  5.05288398])), (array([4.92949575, 3.31313483, 1.39171769, 0.13216361]), array([[0.1276169 , 0.10601967, 0.0214049 , 0.01883297],
#        [0.10601967, 0.15401001, 0.01953699, 0.02218784],
#        [0.0214049 , 0.01953699, 0.0344956 , 0.01394868],
#        [0.01883297, 0.02218784, 0.01394868, 0.02384272]]), array([0.32199196, 1.23594201, 1.19854539, 3.84975236])), (array([6.37578569, 2.93361081, 5.40024292, 2.18999692]), array([[ 0.47779152,  0.09320541,  0.36423354, -0.03938397],
#        [ 0.09320541,  0.10631035,  0.06615481,  0.02181322],
#        [ 0.36423354,  0.06615481,  0.35731247, -0.0319485 ],
#        [-0.03938397,  0.02181322, -0.0319485 ,  0.07554387]]), array([ 6.21025658,  3.44802407,  4.66148558, -3.32321984]))]

# %%
# Check the clustering performance

from fmvmm.utils.utils_mixture import clustering_metrics

# To get the predictions for all the models

cluster_list = model.predict()

# To get the predictions for the best model

best_cluster = model.best_predict()

clustering_metrics(iris.target, best_cluster)
# Out:
# {'accuracy': 0.9066666666666666,
#  'precision': 0.9270833333333334,
#  'recall': 0.9066666666666666,
#  'f_score': 0.9048007615939072}

# %%
# Get the top performing models with the BIC values

model.get_top_mixtures()
# Out:
# [(619.02757150221,
#   ['fmvmm.distributions.multivariate_t',
#    'fmvmm.distributions.multivariate_t',
#    'fmvmm.distributions.multivariate_t']),
#  (620.353445765102,
#   ['fmvmm.distributions.multivariate_skewnorm',
#    'fmvmm.distributions.multivariate_t',
#    'fmvmm.distributions.multivariate_t']),
#  (624.7352466964519,
#   ['fmvmm.distributions.multivariate_skewnorm',
#    'fmvmm.distributions.multivariate_skewnorm',
#    'fmvmm.distributions.multivariate_t']),
#  (630.1454727198909,
#   ['fmvmm.distributions.multivariate_skewnorm',
#    'fmvmm.distributions.multivariate_skewnorm',
#    'fmvmm.distributions.multivariate_skewnorm']),
#  (643.6716859024093,
#   ['fmvmm.distributions.multivariate_norminvgauss',
#    'fmvmm.distributions.multivariate_t',
#    'fmvmm.distributions.multivariate_t']),
#  (647.2280696946323,
#   ['fmvmm.distributions.multivariate_skewnorm',
#    'fmvmm.distributions.multivariate_norminvgauss',
#    'fmvmm.distributions.multivariate_t']),
#  (649.3993592131635,
#   ['fmvmm.distributions.multivariate_genhyperbolic',
#    'fmvmm.distributions.multivariate_t',
#    'fmvmm.distributions.multivariate_t']),
#  (649.9390313024263,
#   ['fmvmm.distributions.multivariate_skewnorm',
#    'fmvmm.distributions.multivariate_skewnorm',
#    'fmvmm.distributions.multivariate